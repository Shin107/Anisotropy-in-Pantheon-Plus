MLE_true=[267.03334333980285, -65.40669273226331, -56.79745748481329, -95.36803460263232, -90.58140077041028, -104.77098992301244, -115.21069005201369, -117.75643766696301, -110.76677170493964, -86.1593074776536, -104.51861287525175, -111.70250721055544, -97.92185051939288, -117.28983486757932, -89.15745594798607, -67.57356339853466, -60.11151707349085]
M0=[-19.14881180460551, -19.30354593163234, -19.294092837123284, -19.334625261631547, -19.33006797741002, -19.293885045223362, -19.349450207949463, -19.310963168089646, -19.335378950619955, -19.31816333412882, -19.30463403974398, -19.312926587822243, -19.28767349329204, -19.314118399631525, -19.292645239741073, -19.334780776387433, -19.308143931426372]
one_sigma_err_CMB_NN= np.array([[5.68471152, 2.67446385, 1.42856556, 1.12901224, 0.82577097,
        0.62970201, 0.35948424, 0.23757261, 0.19869193, 0.15056278,
        0.13986213, 0.12944844, 0.0840875 , 0.06912628, 0.05845371,
        0.0548816 , 0.058676  ],
       [5.74383091, 2.69704156, 1.44352016, 1.13392344, 0.82581606,
        0.62727894, 0.36008995, 0.23319633, 0.19546626, 0.14974062,
        0.13728947, 0.1261235 , 0.08379969, 0.06919197, 0.05851163,
        0.05482454, 0.0584664 ]])

# %%
plt.figure(figsize=(12,10))


plt.errorbar(z_median,qd_HEL_NN,yerr=one_sigma_err_HEL_NN,ls='None',marker='*',color='k',capsize=5,label='Heliocentric frame ($z_{\mathrm{hel}}$)')

plt.errorbar(z_median,qd_CMB_Corr_NN,yerr=one_sigma_err_CMB_NN,ls='None',marker='*',color='cyan',capsize=5,label='CMB frame ($z_{\mathrm{CMB}}$)')
plt.errorbar(z_median,qd_HDCorr_NN,yerr=one_sigma_err_HD_NN,ls='None',marker='*',color='blue',capsize=5,label='CMB frame with peculiar \n velocity corrections ($z_{\mathrm{HD}}$)')

plt.errorbar(z_median,qd_LGCorr_NN,yerr=one_sigma_err_LG_NN,ls='None',marker='*',color='red',capsize=5,label='Local Group Frame ($z_{\mathrm{LG}}$)')
#plt.errorbar(z_median,qd_BFnn,yerr=one_sigma_err_BFnn,ls='None',marker='*',capsize=5,label='Bulk Flow frame')

#plt.plot(z_median,q_LG_temp,'o')


#x_true1=[-47.6567100973159, -15.205016915650473, -7.193299847332989, -4.298098748539335, -3.7810585189491155, -1.6892818919904398, -1.3819310637560824, -0.5876532307789188, -0.2204573798052427, -0.044594000270554206, -0.15284549565040673, -0.18711535577264582, -0.07168914985057888, -0.04828862617254104, -0.13633551130577357, 0.0005996930355684673, -0.012325582348491319]
#x_true=[-39.46448828073347, -17.764075976425733, -8.154178542822148, -4.947257355450127, -4.172154728373906, -2.032317314128067, -1.6006673387504455, -0.7187433885602972, -0.18486719631478643, -0.04675242217956721, -0.1312292952434704, -0.3444986153359629, -0.04605876431737239, -0.10202992257720296, -0.16894997408976506, -0.00814920768025616, -0.03313809274525071]
#plt.plot(z_median,x_true,'o')
plt.grid(ls=':')
plt.xscale('log')
plt.ylim(-50,27)
plt.fill_betweenx(np.linspace(-50,27,10), 0.0, 0.0667, color='gray', alpha=0.2, label='$z<0.0667$')
#plt.legend(loc=(0.45,0.06),fontsize=22)
plt.legend(loc=(0.42,0.06),fontsize=23)

#plt.yscale('symlog')
#plt.xscale('log')
plt.xticks(fontsize=26)
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos: (float(x))))

plt.yticks(fontsize=26)
plt.xlabel('$z_{\\rm{hel}}$',fontsize=36)
plt.ylabel('$q_{\\rm{d}}$',fontsize=36)
plt.text(0.016,17,'C1: sample and redshift  dependent \ncolour and stretch correction',weight='bold',fontsize=22)
#plt.text(0.017,25,'C2: sample and redshift  independent \ncolour and stretch correction',weight='bold',fontsize=20)

#plt.text(0.2,21,'Preliminary results',color='red',fontsize=15)
#plt.savefig('qd_NN_SHELL.pdf')
#plt.plot(z_median,qd['LG'],'o')

# %%
names= ['HEL', 'CMB', 'HD', 'LG']
qd={}
for name in names:
    qd[name] = np.load('qd_'+name+'_age_bias_C1.npy')[0]

# %%
from matplotlib.patches import Patch

frame_handles = [
    Patch(facecolor='k', label=r'Heliocentric frame ($z_{\rm hel}$)'),
    Patch(facecolor='cyan', label=r'CMB frame ($z_{\rm CMB}$)'),
    Patch(facecolor='b', label=r'CMB + pec. vel. ($z_{\rm HD}$)'),
    Patch(facecolor='r', label=r'Local Group frame ($z_{\rm LG}$)')
]

style_handles = [
    Line2D([0], [0], marker='o', color='k', linestyle='None',
           label='No age correction',mfc='w',mew=2),
    Line2D([0], [0], marker='*', color='k', linestyle='None',
           label='With age correction',ms=10)
]

# %%
zindex
name
# Out:
# [7, 8, 0, 9]

# %%
# Out:
# array([-2.75424626e+01, -7.79304580e+00, -3.72929610e+00, -2.24904482e+00,
#        -2.03652664e+00, -7.46419274e-01, -9.81675195e-01, -5.45057457e-01,
#        -1.83140440e-01, -4.93286177e-02, -1.21067909e-01, -2.07378380e-01,
#        -6.80244831e-02, -4.92448104e-02, -1.56046524e-01, -1.34694779e-02,
#        -1.19777733e-02])

# %%
plt.figure(figsize=(12,10))
colors = {0:'b',7:'k',8:'cyan',9:'r'}
colors_2 = {0:"#4484d9",7:"#605f5f",8:"#79d8e9",9:"#fb7270"}
labels= {7:'Heliocentric frame $(z_{\mathrm{hel}})$',8:'CMB frame $(z_{\mathrm{CMB}})$',0:'CMB frame with peculiar \n velocity corrections $(z_{\mathrm{HD}})$',9:'Local Group Frame $(z_{\mathrm{LG}})$'}
non_age = ['hel','cmb','hd','lg'] 
f = 1.04

# Plot with age correction (filled markers)
for z in zindex: 
    name = names[zindex.index(z)]
    z_ar = np.load('qd_'+name+'_age_bias_C1.npy')[0]
    yerr= np.load(f'sigma_qd_tomo_{z}.npy')
    eb = plt.errorbar(z_median*f,z_ar,yerr=yerr,marker='*',ls = 'None',capsize = 3,color=colors[z],markersize=7,elinewidth=2)
    eb[-1][0].set_linestyle('-')

# Plot without age correction (open circles)
# for el in non_age:
#     err= globals()[f'one_sigma_err_{el}_qd_lane_c2']
#     qd = globals()[f'qd_{el}_c2_lane']
#     plt.errorbar(z_median/f,qd,yerr=err,fmt='o',capsize = 3,ms=7,lw=2,alpha=0.9,color=colors_2[zindex[non_age.index(el)]],mfc='white',mew=2)

plt.errorbar(z_median/f,qd_HEL_NN,yerr=one_sigma_err_HEL_NN,ls='None',marker='o',color="#605f5f",alpha=0.9,capsize=5,label='Heliocentric frame ($z_{\mathrm{hel}}$)',mfc='white',mew=2)

plt.errorbar(z_median/f,qd_CMB_Corr_NN,yerr=one_sigma_err_CMB_NN,ls='None',marker='o',color="#79d8e9",alpha=0.9,capsize=5,label='CMB frame ($z_{\mathrm{CMB}}$)',mfc='white',mew=2)
plt.errorbar(z_median/f,qd_HDCorr_NN,yerr=one_sigma_err_HD_NN,ls='None',marker='o',color="#4484d9",alpha=0.9,capsize=5,label='CMB frame with peculiar \n velocity corrections ($z_{\mathrm{HD}}$)',mfc='white',mew=2)

plt.errorbar(z_median/f,qd_LGCorr_NN,yerr=one_sigma_err_LG_NN,ls='None',marker='o',color="#fb7270",alpha=0.9,capsize=5,label='Local Group Frame ($z_{\mathrm{LG}}$)',mfc='white',mew=2)

plt.xscale('log')
plt.ylim(-50,25)
plt.xlim(0.004, 1.0)

# Gray shaded region
plt.fill_betweenx(np.linspace(-50,35,100), 0.0, 0.0667, color='gray', alpha=0.2, zorder=0)

# Grid
plt.grid(ls=':', alpha=0.6, linewidth=1)

# Legends
leg1 = plt.legend(
    handles=frame_handles,
    loc=(0.45, 0.69),
    fontsize=22,
    frameon=False,
)
leg2 = plt.legend(
    handles=style_handles,
    loc=(0.50, 0.2),
    fontsize=22,
    frameon=False
)
plt.gca().add_artist(leg1)

# Axis formatting
plt.xticks(fontsize=26)
plt.yticks(fontsize=26)
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x,p: f'{float(x):.3g}'))

plt.xlabel('$z_{\\rm{hel}}$',fontsize=36)
plt.ylabel('$q_{\\rm{d}}$',fontsize=36)

plt.tight_layout()
# plt.savefig('3n3n_age_bias.pdf',dpi=300,bbox_inches='tight')
plt.savefig('age_bias_C1.pdf',dpi=300,bbox_inches='tight')

# %%
z_ar
# Out:
# array([-16.89466213,  -8.99680159,  -4.62344278,  -1.97652107,
#         -2.25299488,  -0.17017621,  -1.30206207,  -0.25177194,
#         -0.48180787,  -0.17178085,  -0.53555735,  -0.49488405,
#         -0.21090843,   0.07688868,  -0.90580095,  -0.4044064 ,
#          0.40303298])

# %%
MLE_true = np.load(f'MLE_11.npy')
x_true = np.load(f'Tomo_vals/z_ar_11.npy')

# %%
MLE_true
# Out:
# array([1230.81906816,  204.216995  ,  151.93053221,   52.3107509 ,
#          51.78038885,   81.76915297,   -5.99383248,  -53.50991151,
#         -51.94189725,  -45.87247823,  -39.20464322,  -28.54701995,
#         -47.07137694,  -77.67050082,   42.39377827,    4.86878029,
#         -15.50967213])
